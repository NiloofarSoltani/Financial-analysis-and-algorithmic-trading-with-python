# %% [markdown]
# <div style="background-color: #4C0053; padding:15px;" ><h2> Time Series in Pandas

# %% [markdown]
# <div style="background-color: #4C0033; padding:15px;" ><h2> DateTime Index

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
from datetime import datetime
# %matplotlib inline

# %%
my_year = 2020
my_month = 6
ma_day = 6
my_hour = 20
my_minute = 20
my_second = 20

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2> Create specific time

# %%
my_date = datetime(my_year,my_month,ma_day)
my_date
# Out:
# datetime.datetime(2020, 6, 6, 0, 0)

# %%
my_date_time = datetime(my_year,my_month,ma_day,my_hour,my_minute,my_second)
my_date_time
# Out:
# datetime.datetime(2020, 6, 6, 20, 20, 20)

# %%
my_date_time.year
# Out:
# 2020

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2> Showing date and time at the moment

# %%
my_date_time.now()
# Out:
# datetime.datetime(2023, 6, 5, 19, 36, 14, 952577)

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2> Converting List to time Index and asign it to a dataset

# %%
first_two = [datetime(2020,2,2),datetime(2021,1,1),datetime(2020,2,22),datetime(2022,2,22)]
print(first_two , f'This is a {type(first_two)}')
# Out:
# [datetime.datetime(2020, 2, 2, 0, 0), datetime.datetime(2021, 1, 1, 0, 0), datetime.datetime(2020, 2, 22, 0, 0), datetime.datetime(2022, 2, 22, 0, 0)] This is a <class 'list'>

# %%
# convert this first_two variable made of the dates into index
dt_ind = pd.DatetimeIndex(first_two)
dt_ind
# Out:
# DatetimeIndex(['2020-02-02', '2021-01-01', '2020-02-22', '2022-02-22'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(4,3)
cols = ['a','b','c']
df = pd.DataFrame(data,dt_ind,cols)
df
# Out:
#                    a         b         c
# 2020-02-02 -0.794958 -0.740251  0.515864
# 2021-01-01 -1.327363 -1.552615  0.330780
# 2020-02-22 -0.224620  1.077773 -0.173034
# 2022-02-22  0.323435  1.330357  0.468121

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2> different method on the date time index

# %% [markdown]
# ***the index of the max date of index columns***

# %%
df.index.argmax()
# Out:
# 3

# %%
df.index.max()
# Out:
# Timestamp('2022-02-22 00:00:00')

# %%
df.index.argmin()
# Out:
# 0

# %%
df.index.min()
# Out:
# Timestamp('2020-02-02 00:00:00')

# %% [markdown]
# <div style="background-color: #4C0033; padding:15px;" ><h2> Time Resampling<br />In order to sampling we need to Conver string time cell to datetime index cell

# %%
df = pd.read_csv('D://pythonInternship//finantioal-analaysis//documentation_file//walmart_stock.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
df.info()  #Date column is a string object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2>WAY 1:

# %%
df['Date'] = pd.to_datetime(df['Date'])  #==> df['Date'].apply(pd.to_datetime)
df.info()  #now it is datetime object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
df.set_index('Date',inplace=True)
df
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215
# ...               ...        ...        ...        ...       ...        ...
# 2016-12-23  69.430000  69.750000  69.360001  69.540001   4803900  69.032411
# 2016-12-27  69.300003  69.820000  69.250000  69.699997   4435700  69.191240
# 2016-12-28  69.940002  70.000000  69.260002  69.309998   4875700  68.804087
# 2016-12-29  69.209999  69.519997  69.120003  69.260002   4298400  68.754456
# 2016-12-30  69.120003  69.430000  68.830002  69.120003   6889500  68.615479
#
# [1258 rows x 6 columns]

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2>WAY 2:

# %%
df = pd.read_csv('D://pythonInternship//finantioal-analaysis//documentation_file//walmart_stock.csv',index_col='Date',parse_dates=True) #,parse_dates=True will change the type of date from string object to datetime
df.index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2>RESAMPLING

# %%
df.resample(rule='A').mean()
# rule is te way we want to resampling going to be done | there is keywords for any kind of possible time series offset strings
# A -> year and frequency
# B -> business day frequency
# C -> custom business day frequency
# D -> calander day frequency ,....
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-12-31  67.158680  67.602120  66.786520  67.215120  9.239015e+06
# 2013-12-31  75.264048  75.729405  74.843055  75.320516  6.951496e+06
# 2014-12-31  77.274524  77.740040  76.864405  77.327381  6.515612e+06
# 2015-12-31  72.569405  73.064167  72.034802  72.491111  9.040769e+06
# 2016-12-31  69.481349  70.019643  69.023492  69.547063  9.371645e+06
#
#             Adj Close
# Date
# 2012-12-31  59.389349
# 2013-12-31  68.147179
# 2014-12-31  71.709712
# 2015-12-31  68.831426
# 2016-12-31  68.054229

# %%
df.resample(rule='Q').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-03-31  60.462903  60.807258  60.160484  60.519516  8.850221e+06
# 2012-06-30  62.888889  63.400159  62.592222  63.057143  1.155795e+07
# 2012-09-30  73.081587  73.549682  72.717619  73.174921  7.871587e+06
# 2012-12-31  72.174678  72.623226  71.647741  72.079839  8.660958e+06
# 2013-03-31  70.898834  71.393000  70.552666  71.026000  8.482003e+06
# 2013-06-30  76.873906  77.417813  76.413281  76.885781  7.656086e+06
# 2013-09-30  75.637969  76.030469  75.213594  75.629063  5.796625e+06
# 2013-12-31  77.372656  77.805313  76.924531  77.472813  5.966927e+06
# 2014-03-31  75.339344  75.802787  74.863278  75.337213  7.050402e+06
# 2014-06-30  77.036508  77.391111  76.689524  77.066508  6.048765e+06
# 2014-09-30  75.674843  76.062501  75.375938  75.748593  5.550031e+06
# 2014-12-31  80.952969  81.607500  80.432344  81.059844  7.431025e+06
# ...

# %%
df.resample(rule='BQ').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-03-30  60.462903  60.807258  60.160484  60.519516  8.850221e+06
# 2012-06-29  62.888889  63.400159  62.592222  63.057143  1.155795e+07
# 2012-09-28  73.081587  73.549682  72.717619  73.174921  7.871587e+06
# 2012-12-31  72.174678  72.623226  71.647741  72.079839  8.660958e+06
# 2013-03-29  70.898834  71.393000  70.552666  71.026000  8.482003e+06
# 2013-06-28  76.873906  77.417813  76.413281  76.885781  7.656086e+06
# 2013-09-30  75.637969  76.030469  75.213594  75.629063  5.796625e+06
# 2013-12-31  77.372656  77.805313  76.924531  77.472813  5.966927e+06
# 2014-03-31  75.339344  75.802787  74.863278  75.337213  7.050402e+06
# 2014-06-30  77.036508  77.391111  76.689524  77.066508  6.048765e+06
# 2014-09-30  75.674843  76.062501  75.375938  75.748593  5.550031e+06
# 2014-12-31  80.952969  81.607500  80.432344  81.059844  7.431025e+06
# ...

# %%
df.resample(rule='A').max()  # this will give me thw max price per a year
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-12-31  77.599998  77.599998  76.690002  77.150002  38007300  68.568371
# 2013-12-31  81.209999  81.370003  80.820000  81.209999  25683700  73.929868
# 2014-12-31  87.080002  88.089996  86.480003  87.540001  22812400  81.707680
# 2015-12-31  90.800003  90.970001  89.250000  90.470001  80898100  84.914216
# 2016-12-31  74.500000  75.190002  73.629997  74.300003  35076700  73.233524

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px;" ><h2>How we can show the information of the first day of a year

# %%
def first_day(entry):
    return entry[0]

df.resample(rule='A').apply(first_day)
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-12-31  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2013-12-31  68.930000  69.239998  68.449997  69.239998  10390800  61.879708
# 2014-12-31  78.720001  79.470001  78.500000  78.910004   6878000  72.254228
# 2015-12-31  86.269997  86.720001  85.550003  85.900002   4501800  80.624861
# 2016-12-31  60.500000  61.490002  60.360001  61.459999  11989200  59.289713

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h2>VISUALIZATION RESAMPLING

# %%
df['Close'].resample('A').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].resample(rule='M').mean().plot(kind='bar',figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <div style="background-color: #4C0033; padding:15px;" ><h2> Time Shifting

# %%
df = pd.read_csv('D://pythonInternship//finantioal-analaysis//documentation_file//walmart_stock.csv',index_col='Date',parse_dates=True)
df.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
df.tail()
# Out:
#                  Open       High        Low      Close   Volume  Adj Close
# Date
# 2016-12-23  69.430000  69.750000  69.360001  69.540001  4803900  69.032411
# 2016-12-27  69.300003  69.820000  69.250000  69.699997  4435700  69.191240
# 2016-12-28  69.940002  70.000000  69.260002  69.309998  4875700  68.804087
# 2016-12-29  69.209999  69.519997  69.120003  69.260002  4298400  68.754456
# 2016-12-30  69.120003  69.430000  68.830002  69.120003  6889500  68.615479

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h2> SHIFT DATA to another cell - index row is fixed

# %%
shdf = df.shift(periods=1)
shdf.head() # first record will be nan
# Out:
#                  Open       High        Low      Close      Volume  Adj Close
# Date
# 2012-01-03        NaN        NaN        NaN        NaN         NaN        NaN
# 2012-01-04  59.970001  61.060001  59.869999  60.330002  12668800.0  52.619235
# 2012-01-05  60.209999  60.349998  59.470001  59.709999   9593300.0  52.078475
# 2012-01-06  59.349998  59.619999  58.369999  59.419998  12768200.0  51.825539
# 2012-01-09  59.419998  59.450001  58.869999  59.000000   8069400.0  51.459220

# %%
shdf.tail() # we lose last one record
# Out:
#                  Open       High        Low      Close      Volume  Adj Close
# Date
# 2016-12-23  71.239998  71.239998  69.209999  69.589996  12106800.0  69.082042
# 2016-12-27  69.430000  69.750000  69.360001  69.540001   4803900.0  69.032411
# 2016-12-28  69.300003  69.820000  69.250000  69.699997   4435700.0  69.191240
# 2016-12-29  69.940002  70.000000  69.260002  69.309998   4875700.0  68.804087
# 2016-12-30  69.209999  69.519997  69.120003  69.260002   4298400.0  68.754456

# %%
df.shift(periods=-1)
df
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215
# ...               ...        ...        ...        ...       ...        ...
# 2016-12-23  69.430000  69.750000  69.360001  69.540001   4803900  69.032411
# 2016-12-27  69.300003  69.820000  69.250000  69.699997   4435700  69.191240
# 2016-12-28  69.940002  70.000000  69.260002  69.309998   4875700  68.804087
# 2016-12-29  69.209999  69.519997  69.120003  69.260002   4298400  68.754456
# 2016-12-30  69.120003  69.430000  68.830002  69.120003   6889500  68.615479
#
# [1258 rows x 6 columns]

# %% [markdown]
# <div style="background-color: #4C0033; padding:15px;" ><h2> Rolling and Expanding

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h4>we can use rolling mean (MOVING AVERAGE) to get more signal about the general trend of the data<br /> convert daily show to weekly

# %%
df['Open'].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df.rolling(7).mean().head(20) # bcs the mean is for 7 days 6 first record are nan
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-01-03        NaN        NaN        NaN        NaN           NaN
# 2012-01-04        NaN        NaN        NaN        NaN           NaN
# 2012-01-05        NaN        NaN        NaN        NaN           NaN
# 2012-01-06        NaN        NaN        NaN        NaN           NaN
# 2012-01-09        NaN        NaN        NaN        NaN           NaN
# 2012-01-10        NaN        NaN        NaN        NaN           NaN
# 2012-01-11  59.495714  59.895714  59.074285  59.440000  9.007414e+06
# 2012-01-12  59.469999  59.744285  59.007143  59.321429  8.231357e+06
# 2012-01-13  59.322857  59.638571  58.941428  59.297143  7.965071e+06
# 2012-01-17  59.397143  59.708571  59.105714  59.358572  7.355329e+06
# 2012-01-18  59.450000  59.791428  59.217143  59.502857  7.047043e+06
# 2012-01-19  59.578572  59.960000  59.335715  59.707143  7.412086e+06
# ...

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h4> convert daily show to weekly

# %%
df['Open'].plot()
df.rolling(window=7).mean()['Close'].plot(figsize=(16,6))
df.rolling(window=30).mean()['Close'].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h4>Put Legend in the plot <br />pandas automaticly put it when you have 2+ columns to show

# %%
df['Close 30 Day MA'] = df['Close'].rolling(window=30).mean()
df[['Close 30 Day MA','Close']].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h4> it is the average of all before

# %%
df['Close'].expanding().mean().plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].expanding(min_periods=7).mean().plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <div style="background-color: #4C0033; padding:15px;" ><h2> Bollinger Bands

# %%
# Close 20 MA
df['Close: 20 Day Mean'] = df['Close'].rolling(20).mean()

# Upper = 20MA + 2*std(20)
df['Upper'] = df['Close: 20 Day Mean'] + 2*(df['Close'].rolling(20).std())

# Lower = 20MA - 2*std(20)
df['Lower'] = df['Close: 20 Day Mean'] - 2*(df['Close'].rolling(20).std())

df[['Close','Close: 20 Day Mean','Lower','Upper']].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <div style="background-color: #A75D5D; padding:5px; margin-left:50px" ><h4>we can use rolling mean (MOVING AVERAGE) to get more signal about the general trend of the data<br /> convert daily show to weekly
